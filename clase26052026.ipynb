# %% [markdown]
# <a href="https://colab.research.google.com/github/Perlangas28/Simulacion_1/blob/main/clase26052026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sistema de lìnea de espera con un servidor
#
# **Alumna: Perla Blancas Hernández**
# **Materia:** Simulación 1
# **Prueba aplicada:** Sistema de lìnea de espera con un servidor

# %% [markdown]
# En el siguiente programa simularemos una fila con un solo servidor. Utilizaremos el proceso de Poisson para las llegadas de los clientes y el algoritmo dado en las pàginas 88-90 del libro *Simulation* de Sheldon Ross.

# %% [markdown]
# **Utilizaremos las siguientes variables:**
#
# $t$: tiempo
#
# $N_A$: nùmero de llegadas
#
# $N_D$: nùmero de salidas
#
# **Eventos:**
#
# $t_A$: tiempo de la siguiente llegada
#
# $t_D$: tiempo de la siguiente salida
#
# **Queremos:**
#
# $a)$ Tiempo promedio de un cliente en el sistema.
#
# $b)$ Tiempo en que sale el ùltimo cliente

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
def cola(lam,T):
  t = 0 #reloj del sistema
  n = 0 #numero de clientes en el sistema
  NA = 0 #numero de llegadas
  ND = 0 #numero de salidas

  #eventos
  tA = t0
  tD = math.inf

  LL = []
  SS = []
  CL = []
  T = []

  #CASO 1
  while tA <= tD and tA <= T:

    t = tA
    NA = NA + 1

    n = n + 1

    R = r.random() #U
    t0 = t-((1/lam)*np.log(R))
